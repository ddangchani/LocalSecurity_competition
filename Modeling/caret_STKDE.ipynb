# %% [markdown]
# # Prediction Modeling
# ### with 100M Grid Density/Census data

# %%
import geopandas as gpd
import pandas as pd
from pycaret.regression import *
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns
# for korean plotting
plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['axes.unicode_minus'] = False
import os
os.chdir('/Users/dangchan/Desktop/Github/LocalSecurity_competition')

# %%
# Load files : grid, kderesult, census data
grid = gpd.read_file('data/CENSUS/grid_DJ_100M.gpkg')
density = pd.read_csv('STKDE/result/DJ_100M_sb_700_tb_25.csv')
census = gpd.read_file('df_full_100M.gpkg').fillna(0)

result_grid = density.groupby(['X','Y'], as_index=False).sum()
result_grid = gpd.GeoDataFrame(result_grid['density'], geometry=gpd.points_from_xy(result_grid.X, result_grid.Y), crs='epsg:5181')

# 격자에 병합
grid = grid.sjoin(result_grid, how='left')
grid = grid[grid.columns.drop('index_right')]
grid.density = (grid.density - grid.density.mean()) / grid.density.std() # normalize target density

# census data
df = grid.set_index('GRID_100M_').join(census[census.columns.drop('geometry')].set_index('GRID_100M_')).reset_index(drop=True)
df = df[df.columns.drop('geometry')]

# %%
reg = setup(
    data=df, target="density", session_id=123,
    transformation=True, normalize=True, numeric_imputation='mode',
    remove_multicollinearity=True, multicollinearity_threshold=0.95,
)
# Out:
# <style type="text/css">
# #T_e4642_row7_col1, #T_e4642_row12_col1, #T_e4642_row14_col1, #T_e4642_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e4642">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4642_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e4642_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4642_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e4642_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e4642_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_e4642_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e4642_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e4642_row1_col1" class="data row1 col1" >density</td>
#     </tr>
#     <tr>
#       <th id="T_e4642_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e4642_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_e4642_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_e4642_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e4642_row3_col0" class="data row3 col0" >Data shape</td>
#       <td id="T_e4642_row3_col1" class="data row3 col1" >(54910, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_e4642_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e4642_row4_col0" class="data row4 col0" >Train data shape</td>
#       <td id="T_e4642_row4_col1" class="data row4 col1" >(38436, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_e4642_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e4642_row5_col0" class="data row5 col0" >Test data shape</td>
#       <td id="T_e4642_row5_col1" class="data row5 col1" >(16474, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_e4642_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e4642_row6_col0" class="data row6 col0" >Numeric features</td>
#       <td id="T_e4642_row6_col1" class="data row6 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_e4642_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e4642_row7_col0" class="data row7 col0" >Preprocess</td>
#       <td id="T_e4642_row7_col1" class="data row7 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e4642_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e4642_row8_col0" class="data row8 col0" >Imputation type</td>
#       <td id="T_e4642_row8_col1" class="data row8 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e4642_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e4642_row9_col0" class="data row9 col0" >Numeric imputation</td>
#       <td id="T_e4642_row9_col1" class="data row9 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_e4642_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e4642_row10_col0" class="data row10 col0" >Categorical imputation</td>
#       <td id="T_e4642_row10_col1" class="data row10 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_e4642_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e4642_row11_col0" class="data row11 col0" >Low variance threshold</td>
#       <td id="T_e4642_row11_col1" class="data row11 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e4642_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e4642_row12_col0" class="data row12 col0" >Remove multicollinearity</td>
#       <td id="T_e4642_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e4642_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e4642_row13_col0" class="data row13 col0" >Multicollinearity threshold</td>
#       <td id="T_e4642_row13_col1" class="data row13 col1" >0.950000</td>
#     </tr>
#     <tr>
#       <th id="T_e4642_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e4642_row14_col0" class="data row14 col0" >Transformation</td>
#       <td id="T_e4642_row14_col1" class="data row14 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e4642_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e4642_row15_col0" class="data row15 col0" >Transformation method</td>
#       <td id="T_e4642_row15_col1" class="data row15 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_e4642_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e4642_row16_col0" class="data row16 col0" >Normalize</td>
#       <td id="T_e4642_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e4642_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e4642_row17_col0" class="data row17 col0" >Normalize method</td>
#       <td id="T_e4642_row17_col1" class="data row17 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_e4642_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e4642_row18_col0" class="data row18 col0" >Fold Generator</td>
#       <td id="T_e4642_row18_col1" class="data row18 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_e4642_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e4642_row19_col0" class="data row19 col0" >Fold Number</td>
#       <td id="T_e4642_row19_col1" class="data row19 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e4642_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_e4642_row20_col0" class="data row20 col0" >CPU Jobs</td>
#       <td id="T_e4642_row20_col1" class="data row20 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e4642_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_e4642_row21_col0" class="data row21 col0" >Use GPU</td>
#       <td id="T_e4642_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e4642_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_e4642_row22_col0" class="data row22 col0" >Log Experiment</td>
#       <td id="T_e4642_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e4642_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_e4642_row23_col0" class="data row23 col0" >Experiment Name</td>
#       <td id="T_e4642_row23_col1" class="data row23 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e4642_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_e4642_row24_col0" class="data row24 col0" >USI</td>
#       <td id="T_e4642_row24_col1" class="data row24 col1" >9345</td>
#     </tr>
#   </tbody>
# </table>

# %%
reg.compare_models(errors='raise')
# Out:
# <style type="text/css">
# #T_5d56d th {
#   text-align: left;
# }
# #T_5d56d_row0_col0, #T_5d56d_row0_col1, #T_5d56d_row0_col5, #T_5d56d_row0_col6, #T_5d56d_row1_col0, #T_5d56d_row1_col1, #T_5d56d_row1_col2, #T_5d56d_row1_col3, #T_5d56d_row1_col4, #T_5d56d_row1_col5, #T_5d56d_row1_col6, #T_5d56d_row2_col0, #T_5d56d_row2_col1, #T_5d56d_row2_col2, #T_5d56d_row2_col3, #T_5d56d_row2_col4, #T_5d56d_row2_col5, #T_5d56d_row2_col6, #T_5d56d_row3_col0, #T_5d56d_row3_col1, #T_5d56d_row3_col2, #T_5d56d_row3_col3, #T_5d56d_row3_col4, #T_5d56d_row3_col5, #T_5d56d_row3_col6, #T_5d56d_row4_col0, #T_5d56d_row4_col1, #T_5d56d_row4_col2, #T_5d56d_row4_col3, #T_5d56d_row4_col4, #T_5d56d_row4_col5, #T_5d56d_row4_col6, #T_5d56d_row5_col0, #T_5d56d_row5_col1, #T_5d56d_row5_col2, #T_5d56d_row5_col3, #T_5d56d_row5_col4, #T_5d56d_row5_col5, #T_5d56d_row5_col6, #T_5d56d_row6_col0, #T_5d56d_row6_col1, #T_5d56d_row6_col2, #T_5d56d_row6_col3, #T_5d56d_row6_col4, #T_5d56d_row6_col5, #T_5d56d_row6_col6, #T_5d56d_row7_col0, #T_5d56d_row7_col2, #T_5d56d_row7_col3, #T_5d56d_row7_col4, #T_5d56d_row7_col6, #T_5d56d_row8_col0, #T_5d56d_row8_col1, #T_5d56d_row8_col2, #T_5d56d_row8_col3, #T_5d56d_row8_col4, #T_5d56d_row8_col5, #T_5d56d_row8_col6, #T_5d56d_row9_col0, #T_5d56d_row9_col1, #T_5d56d_row9_col2, #T_5d56d_row9_col3, #T_5d56d_row9_col4, #T_5d56d_row9_col5, #T_5d56d_row10_col0, #T_5d56d_row10_col1, #T_5d56d_row10_col2, #T_5d56d_row10_col3, #T_5d56d_row10_col4, #T_5d56d_row10_col5, #T_5d56d_row11_col0, #T_5d56d_row11_col1, #T_5d56d_row11_col2, #T_5d56d_row11_col3, #T_5d56d_row11_col4, #T_5d56d_row11_col5, #T_5d56d_row12_col0, #T_5d56d_row12_col1, #T_5d56d_row12_col2, #T_5d56d_row12_col3, #T_5d56d_row12_col4, #T_5d56d_row12_col5, #T_5d56d_row13_col0, #T_5d56d_row13_col1, #T_5d56d_row13_col2, #T_5d56d_row13_col3, #T_5d56d_row13_col4, #T_5d56d_row13_col5, #T_5d56d_row13_col6, #T_5d56d_row14_col0, #T_5d56d_row14_col1, #T_5d56d_row14_col2, #T_5d56d_row14_col3, #T_5d56d_row14_col4, #T_5d56d_row14_col5, #T_5d56d_row14_col6, #T_5d56d_row15_col0, #T_5d56d_row15_col1, #T_5d56d_row15_col2, #T_5d56d_row15_col3, #T_5d56d_row15_col4, #T_5d56d_row15_col5, #T_5d56d_row15_col6, #T_5d56d_row16_col0, #T_5d56d_row16_col1, #T_5d56d_row16_col2, #T_5d56d_row16_col3, #T_5d56d_row16_col4, #T_5d56d_row16_col5, #T_5d56d_row16_col6, #T_5d56d_row17_col0, #T_5d56d_row17_col1, #T_5d56d_row17_col2, #T_5d56d_row17_col3, #T_5d56d_row17_col4, #T_5d56d_row17_col5, #T_5d56d_row17_col6, #T_5d56d_row18_col0, #T_5d56d_row18_col1, #T_5d56d_row18_col2, #T_5d56d_row18_col3, #T_5d56d_row18_col4, #T_5d56d_row18_col5, #T_5d56d_row18_col6, #T_5d56d_row19_col0, #T_5d56d_row19_col1, #T_5d56d_row19_col2, #T_5d56d_row19_col3, #T_5d56d_row19_col4, #T_5d56d_row19_col5, #T_5d56d_row19_col6 {
#   text-align: left;
# }
# #T_5d56d_row0_col2, #T_5d56d_row0_col3, #T_5d56d_row0_col4, #T_5d56d_row7_col1, #T_5d56d_row7_col5, #T_5d56d_row9_col6, #T_5d56d_row10_col6, #T_5d56d_row11_col6, #T_5d56d_row12_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_5d56d_row0_col7, #T_5d56d_row1_col7, #T_5d56d_row2_col7, #T_5d56d_row3_col7, #T_5d56d_row4_col7, #T_5d56d_row5_col7, #T_5d56d_row6_col7, #T_5d56d_row7_col7, #T_5d56d_row8_col7, #T_5d56d_row9_col7, #T_5d56d_row11_col7, #T_5d56d_row12_col7, #T_5d56d_row13_col7, #T_5d56d_row14_col7, #T_5d56d_row15_col7, #T_5d56d_row16_col7, #T_5d56d_row17_col7, #T_5d56d_row18_col7, #T_5d56d_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_5d56d_row10_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_5d56d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d56d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5d56d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_5d56d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_5d56d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_5d56d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_5d56d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_5d56d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_5d56d_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d56d_level0_row0" class="row_heading level0 row0" >ada</th>
#       <td id="T_5d56d_row0_col0" class="data row0 col0" >AdaBoost Regressor</td>
#       <td id="T_5d56d_row0_col1" class="data row0 col1" >0.2169</td>
#       <td id="T_5d56d_row0_col2" class="data row0 col2" >1.0732</td>
#       <td id="T_5d56d_row0_col3" class="data row0 col3" >1.0166</td>
#       <td id="T_5d56d_row0_col4" class="data row0 col4" >0.0716</td>
#       <td id="T_5d56d_row0_col5" class="data row0 col5" >0.2091</td>
#       <td id="T_5d56d_row0_col6" class="data row0 col6" >2.4084</td>
#       <td id="T_5d56d_row0_col7" class="data row0 col7" >0.0520</td>
#     </tr>
#     <tr>
#       <th id="T_5d56d_level0_row1" class="row_heading level0 row1" >br</th>
#       <td id="T_5d56d_row1_col0" class="data row1 col0" >Bayesian Ridge</td>
#       <td id="T_5d56d_row1_col1" class="data row1 col1" >0.2236</td>
#       <td id="T_5d56d_row1_col2" class="data row1 col2" >1.0734</td>
#       <td id="T_5d56d_row1_col3" class="data row1 col3" >1.0171</td>
#       <td id="T_5d56d_row1_col4" class="data row1 col4" >0.0702</td>
#       <td id="T_5d56d_row1_col5" class="data row1 col5" >0.2122</td>
#       <td id="T_5d56d_row1_col6" class="data row1 col6" >2.1775</td>
#       <td id="T_5d56d_row1_col7" class="data row1 col7" >0.0230</td>
#     </tr>
#     <tr>
#       <th id="T_5d56d_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_5d56d_row2_col0" class="data row2 col0" >Linear Regression</td>
#       <td id="T_5d56d_row2_col1" class="data row2 col1" >0.2235</td>
#       <td id="T_5d56d_row2_col2" class="data row2 col2" >1.0735</td>
#       <td id="T_5d56d_row2_col3" class="data row2 col3" >1.0171</td>
#       <td id="T_5d56d_row2_col4" class="data row2 col4" >0.0701</td>
#       <td id="T_5d56d_row2_col5" class="data row2 col5" >0.2122</td>
#       <td id="T_5d56d_row2_col6" class="data row2 col6" >2.1865</td>
#       <td id="T_5d56d_row2_col7" class="data row2 col7" >0.1310</td>
#     </tr>
#     <tr>
#       <th id="T_5d56d_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_5d56d_row3_col0" class="data row3 col0" >Ridge Regression</td>
#       <td id="T_5d56d_row3_col1" class="data row3 col1" >0.2235</td>
#       <td id="T_5d56d_row3_col2" class="data row3 col2" >1.0735</td>
#       <td id="T_5d56d_row3_col3" class="data row3 col3" >1.0171</td>
#       <td id="T_5d56d_row3_col4" class="data row3 col4" >0.0701</td>
#       <td id="T_5d56d_row3_col5" class="data row3 col5" >0.2122</td>
#       <td id="T_5d56d_row3_col6" class="data row3 col6" >2.1864</td>
#       <td id="T_5d56d_row3_col7" class="data row3 col7" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_5d56d_level0_row4" class="row_heading level0 row4" >lar</th>
#       <td id="T_5d56d_row4_col0" class="data row4 col0" >Least Angle Regression</td>
#       <td id="T_5d56d_row4_col1" class="data row4 col1" >0.2239</td>
#       <td id="T_5d56d_row4_col2" class="data row4 col2" >1.0737</td>
#       <td id="T_5d56d_row4_col3" class="data row4 col3" >1.0172</td>
#       <td id="T_5d56d_row4_col4" class="data row4 col4" >0.0699</td>
#       <td id="T_5d56d_row4_col5" class="data row4 col5" >0.2123</td>
#       <td id="T_5d56d_row4_col6" class="data row4 col6" >2.1924</td>
#       <td id="T_5d56d_row4_col7" class="data row4 col7" >0.0230</td>
#     </tr>
#     <tr>
#       <th id="T_5d56d_level0_row5" class="row_heading level0 row5" >omp</th>
#       <td id="T_5d56d_row5_col0" class="data row5 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_5d56d_row5_col1" class="data row5 col1" >0.2455</td>
#       <td id="T_5d56d_row5_col2" class="data row5 col2" >1.0876</td>
#       <td id="T_5d56d_row5_col3" class="data row5 col3" >1.0244</td>
#       <td id="T_5d56
# AdaBoostRegressor(random_state=123)

# %%
gbr = reg.create_model('gbr')
# Out:
# <style type="text/css">
# #T_535cb_row10_col0, #T_535cb_row10_col1, #T_535cb_row10_col2, #T_535cb_row10_col3, #T_535cb_row10_col4, #T_535cb_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_535cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_535cb_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_535cb_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_535cb_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_535cb_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_535cb_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_535cb_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_535cb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_535cb_row0_col0" class="data row0 col0" >0.1998</td>
#       <td id="T_535cb_row0_col1" class="data row0 col1" >0.6980</td>
#       <td id="T_535cb_row0_col2" class="data row0 col2" >0.8355</td>
#       <td id="T_535cb_row0_col3" class="data row0 col3" >0.0440</td>
#       <td id="T_535cb_row0_col4" class="data row0 col4" >0.2003</td>
#       <td id="T_535cb_row0_col5" class="data row0 col5" >1.4793</td>
#     </tr>
#     <tr>
#       <th id="T_535cb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_535cb_row1_col0" class="data row1 col0" >0.2397</td>
#       <td id="T_535cb_row1_col1" class="data row1 col1" >1.5675</td>
#       <td id="T_535cb_row1_col2" class="data row1 col2" >1.2520</td>
#       <td id="T_535cb_row1_col3" class="data row1 col3" >0.0278</td>
#       <td id="T_535cb_row1_col4" class="data row1 col4" >0.2297</td>
#       <td id="T_535cb_row1_col5" class="data row1 col5" >2.1420</td>
#     </tr>
#     <tr>
#       <th id="T_535cb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_535cb_row2_col0" class="data row2 col0" >0.2153</td>
#       <td id="T_535cb_row2_col1" class="data row2 col1" >1.0441</td>
#       <td id="T_535cb_row2_col2" class="data row2 col2" >1.0218</td>
#       <td id="T_535cb_row2_col3" class="data row2 col3" >0.0791</td>
#       <td id="T_535cb_row2_col4" class="data row2 col4" >0.2056</td>
#       <td id="T_535cb_row2_col5" class="data row2 col5" >2.3800</td>
#     </tr>
#     <tr>
#       <th id="T_535cb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_535cb_row3_col0" class="data row3 col0" >0.2255</td>
#       <td id="T_535cb_row3_col1" class="data row3 col1" >1.0516</td>
#       <td id="T_535cb_row3_col2" class="data row3 col2" >1.0255</td>
#       <td id="T_535cb_row3_col3" class="data row3 col3" >0.0769</td>
#       <td id="T_535cb_row3_col4" class="data row3 col4" >0.2164</td>
#       <td id="T_535cb_row3_col5" class="data row3 col5" >3.5020</td>
#     </tr>
#     <tr>
#       <th id="T_535cb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_535cb_row4_col0" class="data row4 col0" >0.2265</td>
#       <td id="T_535cb_row4_col1" class="data row4 col1" >1.1730</td>
#       <td id="T_535cb_row4_col2" class="data row4 col2" >1.0830</td>
#       <td id="T_535cb_row4_col3" class="data row4 col3" >0.0088</td>
#       <td id="T_535cb_row4_col4" class="data row4 col4" >0.2192</td>
#       <td id="T_535cb_row4_col5" class="data row4 col5" >1.7358</td>
#     </tr>
#     <tr>
#       <th id="T_535cb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_535cb_row5_col0" class="data row5 col0" >0.2455</td>
#       <td id="T_535cb_row5_col1" class="data row5 col1" >2.0591</td>
#       <td id="T_535cb_row5_col2" class="data row5 col2" >1.4350</td>
#       <td id="T_535cb_row5_col3" class="data row5 col3" >0.0543</td>
#       <td id="T_535cb_row5_col4" class="data row5 col4" >0.2306</td>
#       <td id="T_535cb_row5_col5" class="data row5 col5" >1.2619</td>
#     </tr>
#     <tr>
#       <th id="T_535cb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_535cb_row6_col0" class="data row6 col0" >0.2007</td>
#       <td id="T_535cb_row6_col1" class="data row6 col1" >0.4937</td>
#       <td id="T_535cb_row6_col2" class="data row6 col2" >0.7026</td>
#       <td id="T_535cb_row6_col3" class="data row6 col3" >0.0591</td>
#       <td id="T_535cb_row6_col4" class="data row6 col4" >0.1938</td>
#       <td id="T_535cb_row6_col5" class="data row6 col5" >1.6974</td>
#     </tr>
#     <tr>
#       <th id="T_535cb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_535cb_row7_col0" class="data row7 col0" >0.2073</td>
#       <td id="T_535cb_row7_col1" class="data row7 col1" >0.8883</td>
#       <td id="T_535cb_row7_col2" class="data row7 col2" >0.9425</td>
#       <td id="T_535cb_row7_col3" class="data row7 col3" >0.0861</td>
#       <td id="T_535cb_row7_col4" class="data row7 col4" >0.1985</td>
#       <td id="T_535cb_row7_col5" class="data row7 col5" >2.6713</td>
#     </tr>
#     <tr>
#       <th id="T_535cb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_535cb_row8_col0" class="data row8 col0" >0.2122</td>
#       <td id="T_535cb_row8_col1" class="data row8 col1" >0.9183</td>
#       <td id="T_535cb_row8_col2" class="data row8 col2" >0.9583</td>
#       <td id="T_535cb_row8_col3" class="data row8 col3" >0.0182</td>
#       <td id="T_535cb_row8_col4" class="data row8 col4" >0.2097</td>
#       <td id="T_535cb_row8_col5" class="data row8 col5" >1.4968</td>
#     </tr>
#     <tr>
#       <th id="T_535cb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_535cb_row9_col0" class="data row9 col0" >0.2189</td>
#       <td id="T_535cb_row9_col1" class="data row9 col1" >1.0065</td>
#       <td id="T_535cb_row9_col2" class="data row9 col2" >1.0032</td>
#       <td id="T_535cb_row9_col3" class="data row9 col3" >0.0611</td>
#       <td id="T_535cb_row9_col4" class="data row9 col4" >0.2179</td>
#       <td id="T_535cb_row9_col5" class="data row9 col5" >4.9313</td>
#     </tr>
#     <tr>
#       <th id="T_535cb_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_535cb_row10_col0" class="data row10 col0" >0.2191</td>
#       <td id="T_535cb_row10_col1" class="data row10 col1" >1.0900</td>
#       <td id="T_535cb_row10_col2" class="data row10 col2" >1.0259</td>
#       <td id="T_535cb_row10_col3" class="data row10 col3" >0.0515</td>
#       <td id="T_535cb_row10_col4" class="data row10 col4" >0.2122</td>
#       <td id="T_535cb_row10_col5" class="data row10 col5" >2.3298</td>
#     </tr>
#     <tr>
#       <th id="T_535cb_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_535cb_row11_col0" class="data row11 col0" >0.0146</td>
#       <td id="T_535cb_row11_col1" class="data row11 col1" >0.4200</td>
#       <td id="T_535cb_row11_col2" class="data row11 col2" >0.1935</td>
#       <td id="T_535cb_row11_col3" class="data row11 col3" >0.0251</td>
#       <td id="T_535cb_row11_col4" class="data row11 col4" >0.0121</td>
#       <td id="T_535cb_row11_col5" class="data row11 col5" >1.0773</td>
#     </tr>
#   </tbody>
# </table>

# %%
tuned_gbr = reg.tune_model(gbr, search_library='scikit-optimize')
# Out:
# <style type="text/css">
# #T_6db63_row10_col0, #T_6db63_row10_col1, #T_6db63_row10_col2, #T_6db63_row10_col3, #T_6db63_row10_col4, #T_6db63_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_6db63">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6db63_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_6db63_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_6db63_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_6db63_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_6db63_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_6db63_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6db63_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6db63_row0_col0" class="data row0 col0" >0.1970</td>
#       <td id="T_6db63_row0_col1" class="data row0 col1" >0.6833</td>
#       <td id="T_6db63_row0_col2" class="data row0 col2" >0.8266</td>
#       <td id="T_6db63_row0_col3" class="data row0 col3" >0.0641</td>
#       <td id="T_6db63_row0_col4" class="data row0 col4" >0.1977</td>
#       <td id="T_6db63_row0_col5" class="data row0 col5" >1.4955</td>
#     </tr>
#     <tr>
#       <th id="T_6db63_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6db63_row1_col0" class="data row1 col0" >0.2364</td>
#       <td id="T_6db63_row1_col1" class="data row1 col1" >1.5139</td>
#       <td id="T_6db63_row1_col2" class="data row1 col2" >1.2304</td>
#       <td id="T_6db63_row1_col3" class="data row1 col3" >0.0610</td>
#       <td id="T_6db63_row1_col4" class="data row1 col4" >0.2267</td>
#       <td id="T_6db63_row1_col5" class="data row1 col5" >2.0973</td>
#     </tr>
#     <tr>
#       <th id="T_6db63_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6db63_row2_col0" class="data row2 col0" >0.2139</td>
#       <td id="T_6db63_row2_col1" class="data row2 col1" >1.0369</td>
#       <td id="T_6db63_row2_col2" class="data row2 col2" >1.0183</td>
#       <td id="T_6db63_row2_col3" class="data row2 col3" >0.0855</td>
#       <td id="T_6db63_row2_col4" class="data row2 col4" >0.2045</td>
#       <td id="T_6db63_row2_col5" class="data row2 col5" >2.4003</td>
#     </tr>
#     <tr>
#       <th id="T_6db63_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6db63_row3_col0" class="data row3 col0" >0.2255</td>
#       <td id="T_6db63_row3_col1" class="data row3 col1" >1.0457</td>
#       <td id="T_6db63_row3_col2" class="data row3 col2" >1.0226</td>
#       <td id="T_6db63_row3_col3" class="data row3 col3" >0.0821</td>
#       <td id="T_6db63_row3_col4" class="data row3 col4" >0.2157</td>
#       <td id="T_6db63_row3_col5" class="data row3 col5" >3.4997</td>
#     </tr>
#     <tr>
#       <th id="T_6db63_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6db63_row4_col0" class="data row4 col0" >0.2223</td>
#       <td id="T_6db63_row4_col1" class="data row4 col1" >1.1115</td>
#       <td id="T_6db63_row4_col2" class="data row4 col2" >1.0543</td>
#       <td id="T_6db63_row4_col3" class="data row4 col3" >0.0608</td>
#       <td id="T_6db63_row4_col4" class="data row4 col4" >0.2153</td>
#       <td id="T_6db63_row4_col5" class="data row4 col5" >1.7277</td>
#     </tr>
#     <tr>
#       <th id="T_6db63_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6db63_row5_col0" class="data row5 col0" >0.2435</td>
#       <td id="T_6db63_row5_col1" class="data row5 col1" >2.0504</td>
#       <td id="T_6db63_row5_col2" class="data row5 col2" >1.4319</td>
#       <td id="T_6db63_row5_col3" class="data row5 col3" >0.0583</td>
#       <td id="T_6db63_row5_col4" class="data row5 col4" >0.2283</td>
#       <td id="T_6db63_row5_col5" class="data row5 col5" >1.2742</td>
#     </tr>
#     <tr>
#       <th id="T_6db63_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6db63_row6_col0" class="data row6 col0" >0.1969</td>
#       <td id="T_6db63_row6_col1" class="data row6 col1" >0.4507</td>
#       <td id="T_6db63_row6_col2" class="data row6 col2" >0.6714</td>
#       <td id="T_6db63_row6_col3" class="data row6 col3" >0.1409</td>
#       <td id="T_6db63_row6_col4" class="data row6 col4" >0.1903</td>
#       <td id="T_6db63_row6_col5" class="data row6 col5" >1.6876</td>
#     </tr>
#     <tr>
#       <th id="T_6db63_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6db63_row7_col0" class="data row7 col0" >0.2080</td>
#       <td id="T_6db63_row7_col1" class="data row7 col1" >0.8894</td>
#       <td id="T_6db63_row7_col2" class="data row7 col2" >0.9431</td>
#       <td id="T_6db63_row7_col3" class="data row7 col3" >0.0850</td>
#       <td id="T_6db63_row7_col4" class="data row7 col4" >0.1991</td>
#       <td id="T_6db63_row7_col5" class="data row7 col5" >2.6564</td>
#     </tr>
#     <tr>
#       <th id="T_6db63_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6db63_row8_col0" class="data row8 col0" >0.2093</td>
#       <td id="T_6db63_row8_col1" class="data row8 col1" >0.8750</td>
#       <td id="T_6db63_row8_col2" class="data row8 col2" >0.9354</td>
#       <td id="T_6db63_row8_col3" class="data row8 col3" >0.0644</td>
#       <td id="T_6db63_row8_col4" class="data row8 col4" >0.2056</td>
#       <td id="T_6db63_row8_col5" class="data row8 col5" >1.4457</td>
#     </tr>
#     <tr>
#       <th id="T_6db63_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6db63_row9_col0" class="data row9 col0" >0.2168</td>
#       <td id="T_6db63_row9_col1" class="data row9 col1" >0.9986</td>
#       <td id="T_6db63_row9_col2" class="data row9 col2" >0.9993</td>
#       <td id="T_6db63_row9_col3" class="data row9 col3" >0.0684</td>
#       <td id="T_6db63_row9_col4" class="data row9 col4" >0.2166</td>
#       <td id="T_6db63_row9_col5" class="data row9 col5" >4.7409</td>
#     </tr>
#     <tr>
#       <th id="T_6db63_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_6db63_row10_col0" class="data row10 col0" >0.2170</td>
#       <td id="T_6db63_row10_col1" class="data row10 col1" >1.0656</td>
#       <td id="T_6db63_row10_col2" class="data row10 col2" >1.0133</td>
#       <td id="T_6db63_row10_col3" class="data row10 col3" >0.0771</td>
#       <td id="T_6db63_row10_col4" class="data row10 col4" >0.2100</td>
#       <td id="T_6db63_row10_col5" class="data row10 col5" >2.3025</td>
#     </tr>
#     <tr>
#       <th id="T_6db63_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_6db63_row11_col0" class="data row11 col0" >0.0146</td>
#       <td id="T_6db63_row11_col1" class="data row11 col1" >0.4207</td>
#       <td id="T_6db63_row11_col2" class="data row11 col2" >0.1967</td>
#       <td id="T_6db63_row11_col3" class="data row11 col3" >0.0235</td>
#       <td id="T_6db63_row11_col4" class="data row11 col4" >0.0119</td>
#       <td id="T_6db63_row11_col5" class="data row11 col5" >1.0348</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_model(tuned_gbr, plot='parameter')
# Out:
#                                     Parameters
# alpha                                      0.9
# ccp_alpha                                  0.0
# criterion                         friedman_mse
# init                                      None
# learning_rate               0.0238190072917794
# loss                             squared_error
# max_depth                                    3
# max_features                0.4284489606984907
# max_leaf_nodes                            None
# min_impurity_decrease     0.002646746704757545
# min_samples_leaf                             5
# min_samples_split                            9
# min_weight_fraction_leaf                   0.0
# n_estimators                               239
# n_iter_no_change                          None
# random_state                               123
# subsample                   0.7687727671549709
# tol                                     0.0001
# validation_fraction                        0.1
# verbose                                      0
# warm_start                               False

# %%
plot_model(tuned_gbr, 'error')

# %%
plot_model(tuned_gbr, 'feature') # 격자당 여성인구(to_in_008)

# %% [markdown]
# ## Prediction

# %%
# Load files : grid, kderesult, census data
grid_SJ = gpd.read_file('data/CENSUS/grid_SJ_100M.gpkg')
census = gpd.read_file('df_full_100M.gpkg').fillna(0)

# census data
df_predict = grid_SJ.set_index('GRID_100M_').join(census[census.columns.drop('geometry')].set_index('GRID_100M_')).reset_index(drop=True)
df_predict = df_predict[df_predict.columns.drop('geometry')]

# %%
df_predict = predict_model(tuned_gbr, data=df_predict)

# %%
grid_SJ['density'] = df_predict['prediction_label']

# %%
grid_SJ.density = (grid_SJ.density - grid_SJ.density.mean()) / grid_SJ.density.std()

# %%
daejeon = gpd.read_file('data/ADM_AREA/대전/LSMD_ADM_SECT_UMD_30.shp', encoding='cp949').to_crs(epsg=5181)
crime_daejeon = gpd.read_file('data/gdf_crime_adm_DJ.gpkg').to_crs(epsg=5181)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8,8))
daejeon.boundary.plot(ax=ax, zorder=2, color='black', linewidth = 0.4)
grid.plot(column = 'density',ax=ax, zorder=1, cmap='Reds', alpha=0.7)
crime_daejeon.geometry.plot(ax=ax, zorder=3, color='red', markersize=2)

ax.set_axis_off()

plt.suptitle('대전 지역 STKDE Result', fontsize=20)
plt.tight_layout()
plt.show()

# %%
# Prediction map
sejong = gpd.read_file('data/ADM_AREA/세종/LSMD_ADM_SECT_UMD_36.shp', encoding='cp949').to_crs(epsg=5181)
crime_sejong = gpd.read_file('data/gdf_crime_adm_SJ.gpkg')
grid_SJ['density'] = grid_SJ['density'] - grid_SJ.density.min() # for better plotting

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8,10))
sejong.boundary.plot(ax=ax, zorder=2, color='black', linewidth = 0.3)
grid_SJ.plot(column = 'density',ax=ax, zorder=1, cmap='Blues', legend=True, legend_kwds={'shrink' : 0.5})
# crime_sejong.geometry.plot(ax=ax, zorder=3, color='red', markersize=1)

ax.set_axis_off()

plt.suptitle('세종 지역 예측 범죄밀도', fontsize=20)
plt.tight_layout()
plt.show()

# %%
# Prediction map
sejong = gpd.read_file('data/ADM_AREA/세종/LSMD_ADM_SECT_UMD_36.shp', encoding='cp949').to_crs(epsg=5181)
crime_sejong = gpd.read_file('data/gdf_crime_adm_SJ.gpkg')
grid_SJ['density'] = grid_SJ['density'] - grid_SJ.density.min() # for better plotting

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8,10))
sejong.boundary.plot(ax=ax, zorder=2, color='black', linewidth = 0.3)
grid_SJ.plot(column = 'density',ax=ax, zorder=1, cmap='Blues', legend=True, legend_kwds={'shrink' : 0.5})
crime_sejong.geometry.plot(ax=ax, zorder=3, color='red', markersize=1)

ax.set_axis_off()

plt.suptitle('세종 지역 예측 범죄밀도', fontsize=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Accuracy
# 전체 세종시 보이스피싱 범죄 $1422$건 중 $1137$건이 density prediction으로 얻어진 격자($N=5982$)에 포함됨</br>
# 오차 포함시(격자 중심부(`centroid`)로부터 $100$m 이내) 총 $1310$건
# $$
# Recall \simeq 0.8 \;\; (0.92\;\text{if 200m error})
# $$

# %%
plus_densities = grid_SJ[grid_SJ.density > 0]
len(plus_densities)
# Out:
# 47370

# %%
crime_grid_idx = crime_sejong.sjoin(grid_SJ)['index_right']
len(crime_grid_idx) # 전체 범죄 수
# Out:
# 1422

# %%
sum([i in plus_densities.index for i in crime_grid_idx])
# Out:
# 1418

# %%
contained = 0
for i in range(len(crime_sejong)):
    arr = np.where(plus_densities.centroid.distance(crime_sejong.geometry[i]) < 100)[0]
    if len(arr) > 0:
        contained += 1
print(contained)
# Out:
# 1422

# %%
sns.kdeplot(grid_SJ.density)
plt.xlabel('norm_density')
plt.grid(visible=False)
plt.xlim([-1,20])
# Out:
# (-1.0, 20.0)
